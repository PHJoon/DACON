# %% [markdown]
# # 코드

# %% [markdown]
# ## Import

# %%
import random
import pandas as pd
import numpy as np
import os
import librosa
import imblearn
import xgboost
import catboost

from tqdm.auto import tqdm

from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
from pycaret.classification import *

import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ## Hyperparameter Setting
# - SR값과 N_MFCC값을 Librosa 패키지에서 사용하는 기본값으로 설정했습니다.
# - SEED 값은 123입니다.

# %%
CFG = {
    'SR':22050,
    'N_MFCC':20, # MFCC 벡터를 추출할 개수
    'SEED':123
}

# %% [markdown]
# ## Fixed Random-Seed

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

seed_everything(CFG['SEED']) # Seed 고정

# %% [markdown]
# ## Data Pre-Processing 1

# %%
train_df = pd.read_csv('./train_data.csv')
test_df = pd.read_csv('./test_data.csv')

# %%
def get_mfcc_feature(df, data_type, save_path):
    # Data Folder path
    root_folder = './'
    if os.path.exists(save_path):
        print(f'{save_path} is exist.')
        return
    features = []
    for uid in tqdm(df['id']):
        root_path = os.path.join(root_folder, data_type)
        path = os.path.join(root_path, str(uid).zfill(5)+'.wav')

        # librosa패키지를 사용하여 wav 파일 load
        y, sr = librosa.load(path, sr=CFG['SR'])
        
        # librosa패키지를 사용하여 mfcc 추출
        mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=CFG['N_MFCC'])

        y_feature = []
        # 추출된 MFCC들의 평균을 Feature로 사용
        for e in mfcc:
            y_feature.append(np.mean(e))
        features.append(y_feature)
    
    # 기존의 자가진단 정보를 담은 데이터프레임에 추출된 오디오 Feature를 추가
    mfcc_df = pd.DataFrame(features, columns=['mfcc_'+str(x) for x in range(1,CFG['N_MFCC']+1)])
    df = pd.concat([df, mfcc_df], axis=1)
    df.to_csv(save_path, index=False)
    print('Done.')

# %%
get_mfcc_feature(train_df, 'train', './train_mfcc_data20_123.csv')
get_mfcc_feature(test_df, 'test', './test_mfcc_data20_123.csv')
# Out:
# ./train_mfcc_data20_123.csv is exist.
# ./test_mfcc_data20_123.csv is exist.

# %% [markdown]
# ## Data Pre-Processing 2

# %%
# wav 파일의 MFCC Feature와 상태정보를 합친 학습데이터를 불러옵니다.
train_df = pd.read_csv('./train_mfcc_data20_123.csv')

# 학습데이터를 모델의 input으로 들어갈 x와 label로 사용할 y로 분할
train_x = train_df.drop(columns=['id', 'covid19'])
train_y = train_df['covid19']

# %%
def onehot_encoding(ohe, x):
    # 학습데이터로 부터 fit된 one-hot encoder (ohe)를 받아 transform 시켜주는 함수
    encoded = ohe.transform(x['gender'].values.reshape(-1,1))
    encoded_df = pd.DataFrame(encoded, columns=ohe.categories_[0])
    x = pd.concat([x.drop(columns=['gender']), encoded_df], axis=1)
    return x

# %%
# 'gender' column의 경우 추가 전처리가 필요 -> OneHotEncoder 적용
ohe = OneHotEncoder(sparse=False)
ohe.fit(train_x['gender'].values.reshape(-1,1))
train_x = onehot_encoding(ohe, train_x)

# %% [markdown]
# # Pycaret
# - Pycaret으로 학습하기 위해 target값인 train_y를 train_x에 다시 합쳤습니다.

# %%
train_x["covid19"] = train_y
train_x.shape
# Out:
# (3805, 27)

# %% [markdown]
# ## Train
# - Categorical 변수 'respiratory_condition', 'fever_or_muscle_pain', 'female', 'male', 'other'를 설정하였습니다.
# - Normalize는 minmax로 진행하였습니다.
# - random state와 같은 역할을 하는 session_id 값은 위에서 설정한 123으로 동일하게 설정했습니다.
# - 불균형 데이터이기 때문에 stratifiedkfold로 진행하였습니다.

# %%
model = setup(data=train_x, target='covid19', session_id=CFG['SEED'], train_size=0.8,
              data_split_stratify=True, data_split_shuffle=True, fold_strategy='stratifiedkfold',
              normalize=True, normalize_method='minmax',
              categorical_features=['respiratory_condition', 'fever_or_muscle_pain', 'female', 'male', 'other'])
# Out:
# <style type="text/css">
# #T_04d9c_row29_col1, #T_04d9c_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_04d9c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_04d9c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_04d9c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_04d9c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_04d9c_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_04d9c_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_04d9c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_04d9c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_04d9c_row1_col1" class="data row1 col1" >covid19</td>
#     </tr>
#     <tr>
#       <th id="T_04d9c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_04d9c_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_04d9c_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_04d9c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_04d9c_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_04d9c_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_04d9c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_04d9c_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_04d9c_row4_col1" class="data row4 col1" >(3805, 27)</td>
#     </tr>
#     <tr>
#       <th id="T_04d9c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_04d9c_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_04d9c_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_04d9c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_04d9c_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_04d9c_row6_col1" class="data row6 col1" >21</td>
#     </tr>
#     <tr>
#       <th id="T_04d9c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_04d9c_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_04d9c_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_04d9c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_04d9c_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_04d9c_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_04d9c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_04d9c_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_04d9c_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_04d9c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_04d9c_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_04d9c_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_04d9c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_04d9c_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_04d9c_row11_col1" class="data row11 col1" >(3044, 26)</td>
#     </tr>
#     <tr>
#       <th id="T_04d9c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_04d9c_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_04d9c_row12_col1" class="data row12 col1" >(761, 26)</td>
#     </tr>
#     <tr>
#       <th id="T_04d9c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_04d9c_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_04d9c_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_04d9c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_04d9c_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_04d9c_row14_col1" class="data row14 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_04d9c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_04d9c_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_04d9c_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_04d9c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_04d9c_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_04d9c_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_04d9c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_04d9c_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_04d9c_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_04d9c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_04d9c_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_04d9c_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_04d9c_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_04d9c_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_04d9c_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_04d9c_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_04d9c_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_04d9c_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_04d9c_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_04d9c_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_04d9c_row21_col1" class="data row21 col1" >69d5</td>
#     </tr>
#     <tr>
#       <th id="T_04d9c_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_04d9c_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_04d9c_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_04d9c_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_04d9c_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_04d9c_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_04d9c_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_04d9c_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_04d9c_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_04d9c_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_04d9c_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_04d9c_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_04d9c_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_04d9c_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_04d9c_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_04d9c_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_04d9c_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_04d9c_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_04d9c_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_04d9c_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_04d9c_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_04d9c_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_04d9c_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_04d9c_row29_col1" class="data row29 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_04d9c_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_04d9c_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_04d9c

# %% [markdown]
# ## Model
# - auc를 기준으로 상위 2개 모델을 뽑았습니다.

# %%
best = compare_models(sort = 'auc', n_select=2, cross_validation=True)
# Out:
# <style type="text/css">
# #T_c4628 th {
#   text-align: left;
# }
# #T_c4628_row0_col0, #T_c4628_row0_col1, #T_c4628_row0_col3, #T_c4628_row0_col4, #T_c4628_row0_col7, #T_c4628_row1_col0, #T_c4628_row1_col1, #T_c4628_row1_col2, #T_c4628_row1_col3, #T_c4628_row1_col4, #T_c4628_row1_col5, #T_c4628_row1_col6, #T_c4628_row1_col7, #T_c4628_row2_col0, #T_c4628_row2_col1, #T_c4628_row2_col2, #T_c4628_row2_col3, #T_c4628_row2_col4, #T_c4628_row2_col5, #T_c4628_row2_col6, #T_c4628_row3_col0, #T_c4628_row3_col1, #T_c4628_row3_col2, #T_c4628_row3_col3, #T_c4628_row3_col4, #T_c4628_row3_col5, #T_c4628_row3_col6, #T_c4628_row3_col7, #T_c4628_row4_col0, #T_c4628_row4_col1, #T_c4628_row4_col2, #T_c4628_row4_col3, #T_c4628_row4_col4, #T_c4628_row4_col5, #T_c4628_row4_col6, #T_c4628_row4_col7, #T_c4628_row5_col0, #T_c4628_row5_col2, #T_c4628_row5_col3, #T_c4628_row5_col4, #T_c4628_row5_col5, #T_c4628_row5_col6, #T_c4628_row5_col7, #T_c4628_row6_col0, #T_c4628_row6_col1, #T_c4628_row6_col2, #T_c4628_row6_col3, #T_c4628_row6_col4, #T_c4628_row6_col5, #T_c4628_row6_col6, #T_c4628_row6_col7, #T_c4628_row7_col0, #T_c4628_row7_col1, #T_c4628_row7_col2, #T_c4628_row7_col4, #T_c4628_row7_col5, #T_c4628_row7_col6, #T_c4628_row7_col7, #T_c4628_row8_col0, #T_c4628_row8_col1, #T_c4628_row8_col2, #T_c4628_row8_col3, #T_c4628_row8_col4, #T_c4628_row8_col5, #T_c4628_row8_col6, #T_c4628_row8_col7, #T_c4628_row9_col0, #T_c4628_row9_col1, #T_c4628_row9_col2, #T_c4628_row9_col3, #T_c4628_row9_col4, #T_c4628_row9_col5, #T_c4628_row9_col6, #T_c4628_row9_col7, #T_c4628_row10_col0, #T_c4628_row10_col1, #T_c4628_row10_col2, #T_c4628_row10_col3, #T_c4628_row10_col4, #T_c4628_row10_col5, #T_c4628_row10_col6, #T_c4628_row10_col7, #T_c4628_row11_col0, #T_c4628_row11_col2, #T_c4628_row11_col3, #T_c4628_row11_col5, #T_c4628_row11_col6, #T_c4628_row11_col7, #T_c4628_row12_col0, #T_c4628_row12_col1, #T_c4628_row12_col2, #T_c4628_row12_col3, #T_c4628_row12_col4, #T_c4628_row12_col5, #T_c4628_row12_col6, #T_c4628_row12_col7, #T_c4628_row13_col0, #T_c4628_row13_col2, #T_c4628_row13_col3, #T_c4628_row13_col4, #T_c4628_row13_col5, #T_c4628_row13_col6, #T_c4628_row13_col7, #T_c4628_row14_col0, #T_c4628_row14_col2, #T_c4628_row14_col3, #T_c4628_row14_col4, #T_c4628_row14_col5, #T_c4628_row14_col6, #T_c4628_row14_col7, #T_c4628_row15_col0, #T_c4628_row15_col1, #T_c4628_row15_col2, #T_c4628_row15_col3, #T_c4628_row15_col4, #T_c4628_row15_col5, #T_c4628_row15_col6, #T_c4628_row15_col7 {
#   text-align: left;
# }
# #T_c4628_row0_col2, #T_c4628_row0_col5, #T_c4628_row0_col6, #T_c4628_row2_col7, #T_c4628_row5_col1, #T_c4628_row7_col3, #T_c4628_row11_col1, #T_c4628_row11_col4, #T_c4628_row13_col1, #T_c4628_row14_col1 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_c4628_row0_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_c4628_row1_col8, #T_c4628_row2_col8, #T_c4628_row3_col8, #T_c4628_row4_col8, #T_c4628_row5_col8, #T_c4628_row6_col8, #T_c4628_row7_col8, #T_c4628_row8_col8, #T_c4628_row9_col8, #T_c4628_row10_col8, #T_c4628_row11_col8, #T_c4628_row12_col8, #T_c4628_row13_col8, #T_c4628_row14_col8, #T_c4628_row15_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_c4628">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c4628_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c4628_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_c4628_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_c4628_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_c4628_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_c4628_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_c4628_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_c4628_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_c4628_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c4628_level0_row0" class="row_heading level0 row0" >nb</th>
#       <td id="T_c4628_row0_col0" class="data row0 col0" >Naive Bayes</td>
#       <td id="T_c4628_row0_col1" class="data row0 col1" >0.8650</td>
#       <td id="T_c4628_row0_col2" class="data row0 col2" >0.7007</td>
#       <td id="T_c4628_row0_col3" class="data row0 col3" >0.3342</td>
#       <td id="T_c4628_row0_col4" class="data row0 col4" >0.2519</td>
#       <td id="T_c4628_row0_col5" class="data row0 col5" >0.2857</td>
#       <td id="T_c4628_row0_col6" class="data row0 col6" >0.2134</td>
#       <td id="T_c4628_row0_col7" class="data row0 col7" >0.2166</td>
#       <td id="T_c4628_row0_col8" class="data row0 col8" >0.0040</td>
#     </tr>
#     <tr>
#       <th id="T_c4628_level0_row1" class="row_heading level0 row1" >lr</th>
#       <td id="T_c4628_row1_col0" class="data row1 col0" >Logistic Regression</td>
#       <td id="T_c4628_row1_col1" class="data row1 col1" >0.9175</td>
#       <td id="T_c4628_row1_col2" class="data row1 col2" >0.6998</td>
#       <td id="T_c4628_row1_col3" class="data row1 col3" >0.0122</td>
#       <td id="T_c4628_row1_col4" class="data row1 col4" >0.1667</td>
#       <td id="T_c4628_row1_col5" class="data row1 col5" >0.0222</td>
#       <td id="T_c4628_row1_col6" class="data row1 col6" >0.0153</td>
#       <td id="T_c4628_row1_col7" class="data row1 col7" >0.0314</td>
#       <td id="T_c4628_row1_col8" class="data row1 col8" >0.4730</td>
#     </tr>
#     <tr>
#       <th id="T_c4628_level0_row2" class="row_heading level0 row2" >lda</th>
#       <td id="T_c4628_row2_col0" class="data row2 col0" >Linear Discriminant Analysis</td>
#       <td id="T_c4628_row2_col1" class="data row2 col1" >0.9139</td>
#       <td id="T_c4628_row2_col2" class="data row2 col2" >0.6983</td>
#       <td id="T_c4628_row2_col3" class="data row2 col3" >0.1790</td>
#       <td id="T_c4628_row2_col4" class="data row2 col4" >0.4332</td>
#       <td id="T_c4628_row2_col5" class="data row2 col5" >0.2507</td>
#       <td id="T_c4628_row2_col6" class="data row2 col6" >0.2130</td>
#       <td id="T_c4628_row2_col7" class="data row2 col7" >0.2380</td>
#       <td id="T_c4628_row2_col8" class="data row2 col8" >0.0060</td>
#     </tr>
#     <tr>
#       <th id="T_c4628_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_c4628_row3_col0" class="data row3 col0" >Extra Trees Classifier</td>
#       <td id="T_c4628_row3_col1" class="data row3 col1" >0.9192</td>
#       <td id="T_c4628_row3_col2" class="data row3 col2" >0.6765</td>
#       <td id="T_c4628_row3_col3" class="data row3 col3" >0.0285</td>
#       <td id="T_c4628_row3_col4" class="data row3 col4" >0.4167</td>
#       <td id="T_c4628_row3_col5" class="data row3 col5" >0.0527</td>
#       <td id="T_c4628_row3_col6" class="data row3 col6" >0.0442</td>
#       <td id="T_c4628_row3_col7" class="data row3 col7" >0.0931</td>
#       <td id="T_c4628_row3_col8" class="data row3 col8" >0.1010</td>
#     </tr>
#     <tr>
#       <th id="T_c4628_level0_row4" class="row_heading level0 row4" >catboost</th>
#       <td id="T_c4628_row4_col0" class="data row4 col0" >CatBoost Classifier</td>
#       <td id="T_c4628_row4_col1" class="data row4 col1" >0.9189</td>
#       <td id="T_c4628_row4_col2" class="data row4 col2" >0.6683</td>
#       <td id="T_c4628_row4_col3" class="data row4 col3" >0.0243</td>
#       <td id="T_c4628_row4_col4" class="data row4 col4" >0.3667</td>
#       <td id="T_c4628_row4_col5" class="data row4 col5" >0.0451</td>
#       <td id="T_c4628_row4_col6" class="data row4 col6" >0.0371</td>
#       <td id="T_c4628_row4_col7" class="data row4 col7" >0.0789</td>
#       <td id="T_c4628_row4_col8" class="data row4 col8" >2.3910</td>
#     </tr>
#     <tr>
#       <th id="T_c4628_level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_c4628_row5_col0" class="data row5 col0" >Random Forest Classifier</td>
#       <td id="T_c4628_row5_col1" class="data row5 col1" >0.9195</td>
#       <td id="T_c4628_row5_col2" class="data row5 col2" >0.6677<

# %% [markdown]
# ## Soft voting
# - Pycaret의 blend_models를 사용하면 기본적으로 soft voting으로 앙상블 해줍니다.

# %%
blender = blend_models(estimator_list=best, optimize='auc', verbose=True)
# Out:
# <style type="text/css">
# #T_71667_row10_col0, #T_71667_row10_col1, #T_71667_row10_col2, #T_71667_row10_col3, #T_71667_row10_col4, #T_71667_row10_col5, #T_71667_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_71667">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_71667_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_71667_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_71667_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_71667_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_71667_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_71667_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_71667_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_71667_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_71667_row0_col0" class="data row0 col0" >0.8852</td>
#       <td id="T_71667_row0_col1" class="data row0 col1" >0.7129</td>
#       <td id="T_71667_row0_col2" class="data row0 col2" >0.2400</td>
#       <td id="T_71667_row0_col3" class="data row0 col3" >0.2727</td>
#       <td id="T_71667_row0_col4" class="data row0 col4" >0.2553</td>
#       <td id="T_71667_row0_col5" class="data row0 col5" >0.1934</td>
#       <td id="T_71667_row0_col6" class="data row0 col6" >0.1939</td>
#     </tr>
#     <tr>
#       <th id="T_71667_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_71667_row1_col0" class="data row1 col0" >0.8885</td>
#       <td id="T_71667_row1_col1" class="data row1 col1" >0.6796</td>
#       <td id="T_71667_row1_col2" class="data row1 col2" >0.2800</td>
#       <td id="T_71667_row1_col3" class="data row1 col3" >0.3043</td>
#       <td id="T_71667_row1_col4" class="data row1 col4" >0.2917</td>
#       <td id="T_71667_row1_col5" class="data row1 col5" >0.2313</td>
#       <td id="T_71667_row1_col6" class="data row1 col6" >0.2315</td>
#     </tr>
#     <tr>
#       <th id="T_71667_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_71667_row2_col0" class="data row2 col0" >0.8984</td>
#       <td id="T_71667_row2_col1" class="data row2 col1" >0.6539</td>
#       <td id="T_71667_row2_col2" class="data row2 col2" >0.2400</td>
#       <td id="T_71667_row2_col3" class="data row2 col3" >0.3333</td>
#       <td id="T_71667_row2_col4" class="data row2 col4" >0.2791</td>
#       <td id="T_71667_row2_col5" class="data row2 col5" >0.2260</td>
#       <td id="T_71667_row2_col6" class="data row2 col6" >0.2295</td>
#     </tr>
#     <tr>
#       <th id="T_71667_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_71667_row3_col0" class="data row3 col0" >0.9016</td>
#       <td id="T_71667_row3_col1" class="data row3 col1" >0.7916</td>
#       <td id="T_71667_row3_col2" class="data row3 col2" >0.3600</td>
#       <td id="T_71667_row3_col3" class="data row3 col3" >0.3913</td>
#       <td id="T_71667_row3_col4" class="data row3 col4" >0.3750</td>
#       <td id="T_71667_row3_col5" class="data row3 col5" >0.3217</td>
#       <td id="T_71667_row3_col6" class="data row3 col6" >0.3220</td>
#     </tr>
#     <tr>
#       <th id="T_71667_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_71667_row4_col0" class="data row4 col0" >0.8882</td>
#       <td id="T_71667_row4_col1" class="data row4 col1" >0.6699</td>
#       <td id="T_71667_row4_col2" class="data row4 col2" >0.1250</td>
#       <td id="T_71667_row4_col3" class="data row4 col3" >0.1875</td>
#       <td id="T_71667_row4_col4" class="data row4 col4" >0.1500</td>
#       <td id="T_71667_row4_col5" class="data row4 col5" >0.0927</td>
#       <td id="T_71667_row4_col6" class="data row4 col6" >0.0949</td>
#     </tr>
#     <tr>
#       <th id="T_71667_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_71667_row5_col0" class="data row5 col0" >0.8816</td>
#       <td id="T_71667_row5_col1" class="data row5 col1" >0.6612</td>
#       <td id="T_71667_row5_col2" class="data row5 col2" >0.1667</td>
#       <td id="T_71667_row5_col3" class="data row5 col3" >0.2000</td>
#       <td id="T_71667_row5_col4" class="data row5 col4" >0.1818</td>
#       <td id="T_71667_row5_col5" class="data row5 col5" >0.1186</td>
#       <td id="T_71667_row5_col6" class="data row5 col6" >0.1191</td>
#     </tr>
#     <tr>
#       <th id="T_71667_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_71667_row6_col0" class="data row6 col0" >0.9013</td>
#       <td id="T_71667_row6_col1" class="data row6 col1" >0.6115</td>
#       <td id="T_71667_row6_col2" class="data row6 col2" >0.2917</td>
#       <td id="T_71667_row6_col3" class="data row6 col3" >0.3500</td>
#       <td id="T_71667_row6_col4" class="data row6 col4" >0.3182</td>
#       <td id="T_71667_row6_col5" class="data row6 col5" >0.2655</td>
#       <td id="T_71667_row6_col6" class="data row6 col6" >0.2667</td>
#     </tr>
#     <tr>
#       <th id="T_71667_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_71667_row7_col0" class="data row7 col0" >0.9112</td>
#       <td id="T_71667_row7_col1" class="data row7 col1" >0.7464</td>
#       <td id="T_71667_row7_col2" class="data row7 col2" >0.2917</td>
#       <td id="T_71667_row7_col3" class="data row7 col3" >0.4118</td>
#       <td id="T_71667_row7_col4" class="data row7 col4" >0.3415</td>
#       <td id="T_71667_row7_col5" class="data row7 col5" >0.2953</td>
#       <td id="T_71667_row7_col6" class="data row7 col6" >0.3004</td>
#     </tr>
#     <tr>
#       <th id="T_71667_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_71667_row8_col0" class="data row8 col0" >0.8750</td>
#       <td id="T_71667_row8_col1" class="data row8 col1" >0.7281</td>
#       <td id="T_71667_row8_col2" class="data row8 col2" >0.2500</td>
#       <td id="T_71667_row8_col3" class="data row8 col3" >0.2308</td>
#       <td id="T_71667_row8_col4" class="data row8 col4" >0.2400</td>
#       <td id="T_71667_row8_col5" class="data row8 col5" >0.1720</td>
#       <td id="T_71667_row8_col6" class="data row8 col6" >0.1722</td>
#     </tr>
#     <tr>
#       <th id="T_71667_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_71667_row9_col0" class="data row9 col0" >0.8882</td>
#       <td id="T_71667_row9_col1" class="data row9 col1" >0.7216</td>
#       <td id="T_71667_row9_col2" class="data row9 col2" >0.3600</td>
#       <td id="T_71667_row9_col3" class="data row9 col3" >0.3333</td>
#       <td id="T_71667_row9_col4" class="data row9 col4" >0.3462</td>
#       <td id="T_71667_row9_col5" class="data row9 col5" >0.2851</td>
#       <td id="T_71667_row9_col6" class="data row9 col6" >0.2854</td>
#     </tr>
#     <tr>
#       <th id="T_71667_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_71667_row10_col0" class="data row10 col0" >0.8919</td>
#       <td id="T_71667_row10_col1" class="data row10 col1" >0.6977</td>
#       <td id="T_71667_row10_col2" class="data row10 col2" >0.2605</td>
#       <td id="T_71667_row10_col3" class="data row10 col3" >0.3015</td>
#       <td id="T_71667_row10_col4" class="data row10 col4" >0.2779</td>
#       <td id="T_71667_row10_col5" class="data row10 col5" >0.2202</td>
#       <td id="T_71667_row10_col6" class="data row10 col6" >0.2216</td>
#     </tr>
#     <tr>
#       <th id="T_71667_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_71667_row11_col0" class="data row11 col0" >0.0104</td>
#       <td id="T_71667_row11_col1" class="data row11 col1" >0.0497</td>
#       <td id="T_71667_row11_col2" class="data row11 col2" >0.0709</td>
#       <td id="T_71667_row11_col3" class="data row11 col3" >0.0733</td>
#       <td id="T_71667_row11_col4

# %%
blender
# Out:
# VotingClassifier(estimators=[('nb',
#                               GaussianNB(priors=None, var_smoothing=1e-09)),
#                              ('lr',
#                               LogisticRegression(C=1.0, class_weight=None,
#                                                  dual=False, fit_intercept=True,
#                                                  intercept_scaling=1,
#                                                  l1_ratio=None, max_iter=1000,
#                                                  multi_class='auto',
#                                                  n_jobs=None, penalty='l2',
#                                                  random_state=123,
#                                                  solver='lbfgs', tol=0.0001,
#                                                  verbose=0,
#                                                  warm_start=False))],
#                  flatten_transform=True, n_jobs=-1, verbose=False,
#                  voting='soft', weights=None)

# %% [markdown]
# ## Train
# - 전체 학습 데이터에 대해서 학습해줍니다.

# %%
final_model = finalize_model(blender)

# %% [markdown]
# ## Inference

# %%
# 위의 학습데이터를 전처리한 과정과 동일하게 test data에도 적용
test_x = pd.read_csv('./test_mfcc_data20_123.csv')
test_x = test_x.drop(columns=['id'])
# Data Leakage에 유의하여 train data로만 학습된 ohe를 사용
test_x = onehot_encoding(ohe, test_x)

# Model 추론
preds = predict_model(final_model, data=test_x)

# %% [markdown]
# ## Submission

# %%
submission = pd.read_csv('./sample_submission.csv')
submission['covid19'] = preds["Label"]
submission.to_csv('./submit_alchmach.csv', index=False)
